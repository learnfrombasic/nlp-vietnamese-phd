# %%
import json
import pymupdf
import xml.etree.ElementTree as ET
from xml.dom import minidom
import re
import unicodedata
from pathlib import Path
import html
from openai import OpenAI
from underthesea import ner

# ──────────────── CẤU HÌNH ────────────────
BOOK_METADATA = {
    "NAM_HOA_KINH": {
        "TITLE": "Nam Hoa Kinh",
        "VOLUME": "",
        "AUTHOR": "Trang Tử",
        "PERIOD": "Chiến Quốc",
        "LANGUAGE": "vi",
        "SOURCE": "thuviensach.vn",
    },
    "TRANG_TU_NAM_HOA_KINH": {
        "TITLE": "Trang Tử Nam Hoa Kinh",
        "VOLUME": "",
        "AUTHOR": "Nguyễn Kim Vỹ",
        "PERIOD": "Chiến Quốc",
        "LANGUAGE": "vi",
        "SOURCE": "Nhà xuất bản văn hóa",
    },
    "TRANG_TU_NAM_HOA_KINH_2": {
        "TITLE": "Trang Tử Nam Hoa Kinh",
        "VOLUME": "",
        "AUTHOR": "Thu Giang, Ngyễn Duy Cần",
        "PERIOD": "Chiến Quốc",
        "LANGUAGE": "vi",
        "SOURCE": "Nhà xuất bản trẻ",
    },
}
BASED_ENTITY_GROUPS = [
    "PER",
    "ORG",
    "LOC",
    "ORG",
    "TME",
    "TITLE",
    "NUM",
]

# %%
import os
import re
import html
import unicodedata
import xml.etree.ElementTree as ET
import xml.dom.minidom as minidom

import pymupdf
import pytesseract
from PIL import Image


def normalize(s: str) -> str:
    return unicodedata.normalize("NFC", s.strip())

def clean_text(text: str) -> str:
    html_entities = {
        "&quot;": "", "&quote;": "", "quot;": "", "quote;": "",
        "&amp;": "&", "&lt;": "<", "&gt;": ">", "&apos;": "'",
        "&nbsp;": " ", "&hellip;": "...", "&mdash;": "—", "&ndash;": "–"
    }
    for entity, replacement in html_entities.items():
        text = text.replace(entity, replacement)
    text = re.sub(r"&[a-zA-Z]+;?", "", text)
    text = re.sub(r"[\u200b\u200e\u202a\u202c\ufeff]+", "", text)
    text = re.sub(r"\s+", " ", text)
    return normalize(text.strip())

def is_vietnamese(text: str) -> bool:
    return bool(re.search(r'[àáảãạăằắẳẵặâầấẩẫậèéẻẽẹêềếểễệìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵđĐ]', text))

def split_sentences(text: str) -> list[str]:
    text = clean_text(text)
    sentences, current = [], ""
    for char in text:
        current += char
        if char in [".", "!", "?", "。"]:
            if len(current.strip()) > 10:
                cleaned = clean_text(current)
                if is_vietnamese(cleaned):
                    sentences.append(cleaned)
            current = ""
    if len(current.strip()) > 10:
        cleaned = clean_text(current)
        if is_vietnamese(cleaned):
            sentences.append(cleaned)
    return sentences

def ocr_page(page) -> str:
    pix = page.get_pixmap(matrix=pymupdf.Matrix(2, 2))
    image = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
    config = r'--oem 3 --psm 6'
    try:
        return clean_text(pytesseract.image_to_string(image, lang='vie', config=config))
    except Exception as e:
        print(f"OCR error: {e}")
        return ""


def build_ocr_xml_with_dynamic_sections(
    pdf_path: str,
    metadata: dict,
    output_path="output_dynamic_ocr.xml",
    code="PKS_001"
):
    print(f"📘 OCR processing PDF: {pdf_path}")
    doc = pymupdf.open(pdf_path)

    root = ET.Element("root")
    file_el = ET.SubElement(root, "FILE", ID=code)

    meta = ET.SubElement(file_el, "meta")
    for tag in ["TITLE", "VOLUME", "AUTHOR", "PERIOD", "LANGUAGE", "TRANSLATOR", "SOURCE"]:
        ET.SubElement(meta, tag).text = metadata.get(tag, "")

    sect_counter = 0
    current_sect = None
    sentence_count = 0

    for page_num in range(len(doc)):
        page_text = ocr_page(doc[page_num])

        # Detect if new section
        chapter_match = re.search(r'\bCHƯƠNG\s+[IVXLCDM\d]+', page_text, re.IGNORECASE)
        if chapter_match:
            sect_counter += 1
            sect_id = f"{code}.{sect_counter:03}"
            current_sect = ET.SubElement(file_el, "SECT", ID=sect_id, NAME=chapter_match.group().strip())
            print(f"🔖 New section: {chapter_match.group().strip()} (Page {page_num+1})")

        if current_sect is None:
            # If no "Chương" found yet, place into unnamed SECT
            current_sect = ET.SubElement(file_el, "SECT", ID=f"{code}.000", NAME="Mở đầu")

        page_id = f"{current_sect.attrib['ID']}.{page_num+1:03}"
        page_el = ET.SubElement(current_sect, "PAGE", ID=page_id)

        sentences = split_sentences(page_text)
        for i, sentence in enumerate(sentences, start=1):
            stc_id = f"{page_id}.{i:02}"
            stc_el = ET.SubElement(page_el, "STC", ID=stc_id)
            stc_el.text = sentence
            sentence_count += 1

    # Save XML
    tree = ET.ElementTree(root)
    pretty_xml = minidom.parseString(ET.tostring(tree.getroot(), encoding="utf-8"))
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(pretty_xml.toprettyxml(indent="  "))

    print(f"✅ XML saved: {output_path}")
    print(f"📊 Total sentences: {sentence_count}, Sections: {sect_counter}")

# %%
pdf_path = "/home/octoopt/workspace/projects/learn-from-basics/nlp-vietnamese-phd/temp/TRANG TỬ NAM HOA KINH.pdf"
code = "PAS_003"
des = f"{code}_nam_hoa_kinh.xml"

metadata = BOOK_METADATA.get("TRANG_TU_NAM_HOA_KINH", {})
build_ocr_xml_with_dynamic_sections(pdf_path, metadata, des, code)
# Out:
# 📘 OCR processing PDF: /home/octoopt/workspace/projects/learn-from-basics/nlp-vietnamese-phd/temp/TRANG TỬ NAM HOA KINH.pdf
# 🔖 New section: chương m (Page 4)
# 🔖 New section: CHƯƠNG I (Page 6)
# 🔖 New section: chương 46 (Page 8)
# 🔖 New section: chương 63 (Page 11)
# 🔖 New section: chương c (Page 14)
# 🔖 New section: chương XXXI (Page 16)
# 🔖 New section: chương X (Page 24)
# 🔖 New section: chương XXX (Page 27)
# 🔖 New section: CHƯƠNG II (Page 32)
# 🔖 New section: chương V (Page 33)
# 🔖 New section: chương XXII (Page 34)
# 🔖 New section: chương M (Page 36)
# 🔖 New section: Chương I (Page 38)
# 🔖 New section: Chương V (Page 39)
# 🔖 New section: chương c (Page 40)
# 🔖 New section: chương c (Page 41)
# 🔖 New section: chương Vi (Page 43)
# 🔖 New section: chương I (Page 46)
# 🔖 New section: chương VII (Page 48)
# 🔖 New section: chương XII (Page 49)
# 🔖 New section: chương c (Page 50)
# 🔖 New section: chương c (Page 51)
# 🔖 New section: CHƯƠNG III (Page 55)
# 🔖 New section: chương XXVII (Page 56)
# 🔖 New section: chương V (Page 58)
# 🔖 New section: chương 1 (Page 60)
# 🔖 New section: CHƯƠNG XXII (Page 396)
# 🔖 New section: Chương C (Page 408)
# 🔖 New section: chương 3 (Page 409)
# 🔖 New section: CHƯƠNG XXIV (Page 411)
# 🔖 New section: chương XXXI (Page 427)
# 🔖 New section: CHƯƠNG XXV (Page 428)
# 🔖 New section: CHƯƠNG XXVI (Page 443)
# 🔖 New section: CHƯƠNG XXVII (Page 453)
# 🔖 New section: CHƯƠNG XXVII (Page 460)
# 🔖 New section: chương L (Page 462)
# 🔖 New section: chương C (Page 470)
# 🔖 New section: chương l (Page 474)
# 🔖 New section: CHƯƠNG XXIX (Page 476)
# 🔖 New section: chương VI (Page 481)
# 🔖 New section: CHƯƠNG XXX (Page 490)
# 🔖 New section: CHƯƠNG XXXI (Page 496)
# 🔖 New section: chương D (Page 503)
# 🔖 New section: CHƯƠNG XXXII (Page 504)
# 🔖 New section: Chương XXXII (Page 515)
# 🔖 New section: CHƯƠNG XXXI (Page 516)
# 🔖 New section: chương c (Page 518)
# 🔖 New section: chương V (Page 520)
# 🔖 New section: chương XXVII (Page 524)
# 🔖 New section: Chương c (Page 533)
# 🔖 New section: CHƯƠNG I (Page 538)
# 🔖 New section: CHƯƠNG II (Page 539)
# 🔖 New section: CHƯƠNG VI (Page 540)
# 🔖 New section: CHƯƠNG XXII (Page 541)
# ✅ XML saved: PAS_003_nam_hoa_kinh.xml
# 📊 Total sentences: 7843, Sections: 124

# %%
import xml.etree.ElementTree as ET


def count_sentences(xml_file_path):
    # Parse the XML file
    tree = ET.parse(xml_file_path)
    root = tree.getroot()

    # Find all STC elements (sentences)
    sentences = root.findall(".//STC")

    # Count the sentences
    total_sentences = len(sentences)

    # Count sentences per section
    sections = {}
    for section in root.findall(".//SECT"):
        section_name = section.get("NAME", "Unknown")
        section_sentences = section.findall(".//STC")
        sections[section_name] = len(section_sentences)

    return total_sentences, sections


# Path to your XML file
xml_file = "/home/octoopt/workspace/projects/learn-from-basics/nlp-vietnamese-phd/nam_hoa_kinh.xml"

# Get the counts
total, section_counts = count_sentences(xml_file)

print(f"Total number of sentences: {total}")
print("\nNumber of sentences per section:")
for section, count in section_counts.items():
    print(f"- {section}: {count} sentences")
# Out:
# Total number of sentences: 2251
#
# Number of sentences per section:
# - Giới thiệu: 2251 sentences

# %%
import pymupdf
import pytesseract
from PIL import Image
import os
import re
import unicodedata
import html

def normalize(s: str) -> str:
    return unicodedata.normalize("NFC", s.strip())

def remove_html_entities(text):
    """Remove HTML entities comprehensively."""
    try:
        text = html.unescape(text)
    except:
        pass
    
    # Remove &quot; and &quote; variations
    text = text.replace("&quot;", "")
    text = text.replace("&quot", "")
    text = text.replace("&quote;", "")
    text = text.replace("&quote", "")
    text = text.replace("quot;", "")
    text = text.replace("quote;", "")
    
    # Remove other common entities
    html_entities = {
        "&amp;": "&", "&lt;": "<", "&gt;": ">", "&apos;": "'",
        "&nbsp;": " ", "&hellip;": "...", "&mdash;": "—", "&ndash;": "–"
    }
    
    for entity, replacement in html_entities.items():
        text = text.replace(entity, replacement)
    
    # Clean remaining entities with regex
    text = re.sub(r"&[a-zA-Z]+;?", "", text)
    
    return text

def clean_text(text: str) -> str:
    """Clean text comprehensively."""
    text = normalize(text)
    text = remove_html_entities(text)
    
    clean_patterns = ["***", "---", "___", "..."]
    for pattern in clean_patterns:
        text = text.replace(pattern, "")
    
    # Remove invisible characters and normalize spaces
    text = re.sub(r"[\u200b\u200e\u202a\u202c\ufeff]+", "", text)
    text = re.sub(r"\s+", " ", text)
    
    return text.strip()

def is_vietnamese(text: str) -> bool:
    """Check if text contains Vietnamese characters."""
    vietnamese_pattern = re.compile(r'[àáảãạăằắẳẵặâầấẩẫậèéẻẽẹêềếểễệìíỉĩịòóỏõọôồốổỗộơờớởỡợùúủũụưừứửữựỳýỷỹỵđĐ]')
    return bool(vietnamese_pattern.search(text))

def extract_images_from_pdf(pdf_path, output_dir="extracted_images"):
    """Extract all images from PDF and save them."""
    os.makedirs(output_dir, exist_ok=True)
    doc = pymupdf.open(pdf_path)
    image_list = []
    
    for page_num in range(len(doc)):
        page = doc[page_num]
        image_dict = page.get_images()
        
        for img_index, img in enumerate(image_dict):
            xref = img[0]
            pix = pymupdf.Pixmap(doc, xref)
            
            if pix.n - pix.alpha < 4:  # GRAY or RGB
                img_filename = f"333_BLOCK{page_num+1:03d}_LINE{img_index+1:03d}.png"
                img_path = os.path.join(output_dir, img_filename)
                pix.save(img_path)
                
                image_list.append({
                    'page': page_num + 1,
                    'filename': img_filename,
                    'path': img_path,
                    'index': img_index + 1
                })
            
            pix = None
    
    doc.close()
    return image_list

def ocr_image(image_path, lang='vie'):
    """Extract text from image using OCR."""
    try:
        # Configure tesseract for Vietnamese
        custom_config = r'--oem 3 --psm 6'
        text = pytesseract.image_to_string(
            Image.open(image_path), 
            lang=lang, 
            config=custom_config
        )
        return clean_text(text)
    except Exception as e:
        print(f"OCR error for {image_path}: {e}")
        return ""

def split_sentences(text: str) -> list[str]:
    """Split text into Vietnamese sentences."""
    text = clean_text(text)
    
    # Split by common sentence delimiters
    sentences = []
    current_sentence = ""
    
    for char in text:
        current_sentence += char
        if char in [".", "!", "?", "。", ";", ":"]:
            if current_sentence.strip():
                cleaned = clean_text(current_sentence)
                # Keep both Vietnamese and meaningful text
                if cleaned and len(cleaned) > 5:
                    sentences.append(cleaned)
            current_sentence = ""
    
    # Add remaining text
    if current_sentence.strip():
        cleaned = clean_text(current_sentence)
        if cleaned and len(cleaned) > 5:
            sentences.append(cleaned)
    
    return sentences

def process_pdf_pages_ocr(
    pdf_path,
    output_file="page_ocr_results.txt",
    start_line=13013,
    max_pages=None,
    verbose=True
):
    """Process entire PDF pages with OCR. Each sentence saved as a line."""
    if verbose:
        print(f"🔄 Processing PDF pages with OCR: {pdf_path}")

    doc = pymupdf.open(pdf_path)
    total_pages = len(doc)
    pages_to_process = min(total_pages, max_pages) if max_pages else total_pages

    results = []
    line_number = start_line
    file = open(output_file, 'w', encoding='utf-8')
    for page_num in range(pages_to_process):
        page = doc[page_num]

        # Convert page to high-res image
        mat = pymupdf.Matrix(2.0, 2.0)
        pix = page.get_pixmap(matrix=mat)
        img_path = f"temp_page_{page_num+1}.png"
        pix.save(img_path)

        if verbose:
            print(f"🔍 OCR page {page_num+1}/{pages_to_process} → {img_path}")

        try:
            ocr_text = ocr_image(img_path)
            sentences = split_sentences(ocr_text) if ocr_text else []

            for i, sentence in enumerate(sentences, start=1):
                if len(sentence.strip()) > 5:
                    filename = f"333_BLOCK{page_num+1:03d}_LINE{i:03d}.png"
                    result_line = f'"{filename}": "{sentence}",'
                    file.write(f"{line_number}\t{result_line}\n")
                    results.append((line_number, result_line))
                    if verbose:
                        print(f"✅ {line_number}: {filename}")
                    line_number += 1

        except Exception as e:
            print(f"❌ Error on page {page_num+1}: {e}")

        finally:
            if os.path.exists(img_path):
                os.remove(img_path)

        pix = None

    doc.close()

    # Write output
    # with open(output_file, 'w', encoding='utf-8') as f:
    #     for line_num, content in results:
    #         f.write(f"{line_num}\t{content}\n")

    if verbose:
        print(f"\n✅ OCR results saved to: {output_file}")
        print(f"📊 Total lines processed: {len(results)}")

    return results
# Out:
# 🔄 Processing PDF pages with OCR: /home/octoopt/workspace/projects/learn-from-basics/nlp-vietnamese-phd/temp/TRANG TỬ NAM HOA KINH.pdf
# 🔍 Processing OCR for page 1
# 🔍 Processing OCR for page 2
# 🔍 Processing OCR for page 3
# 🔍 Processing OCR for page 4
# 🔍 Processing OCR for page 5
# 🔍 Processing OCR for page 6
# 🔍 Processing OCR for page 7
# 🔍 Processing OCR for page 8
# 🔍 Processing OCR for page 9
# 🔍 Processing OCR for page 10
# 🔍 Processing OCR for page 11
# 🔍 Processing OCR for page 12
# 🔍 Processing OCR for page 13
# 🔍 Processing OCR for page 14
# 🔍 Processing OCR for page 15
# 🔍 Processing OCR for page 16
# 🔍 Processing OCR for page 17
# 🔍 Processing OCR for page 18
# 🔍 Processing OCR for page 19
# 🔍 Processing OCR for page 20
# 🔍 Processing OCR for page 21
# 🔍 Processing OCR for page 22
# 🔍 Processing OCR for page 23
# 🔍 Processing OCR for page 24
# 🔍 Processing OCR for page 25
# 🔍 Processing OCR for page 26
# 🔍 Processing OCR for page 27
# 🔍 Processing OCR for page 28
# 🔍 Processing OCR for page 29
# 🔍 Processing OCR for page 30
# 🔍 Processing OCR for page 31
# 🔍 Processing OCR for page 32
# 🔍 Processing OCR for page 33
# 🔍 Processing OCR for page 34
# 🔍 Processing OCR for page 35
# 🔍 Processing OCR for page 36
# 🔍 Processing OCR for page 37
# 🔍 Processing OCR for page 38
# 🔍 Processing OCR for page 39
# 🔍 Processing OCR for page 40
# 🔍 Processing OCR for page 41
# 🔍 Processing OCR for page 42
# 🔍 Processing OCR for page 43
# 🔍 Processing OCR for page 44
# 🔍 Processing OCR for page 45
# 🔍 Processing OCR for page 46
# 🔍 Processing OCR for page 47
# 🔍 Processing OCR for page 48
# 🔍 Processing OCR for page 49
# 🔍 Processing OCR for page 50
# 🔍 Processing OCR for page 51
# 🔍 Processing OCR for page 52
# 🔍 Processing OCR for page 53
# 🔍 Processing OCR for page 54
# 🔍 Processing OCR for page 55
# 🔍 Processing OCR for page 56
# 🔍 Processing OCR for page 57
# 🔍 Processing OCR for page 58
# 🔍 Processing OCR for page 59
# 🔍 Processing OCR for page 60
# 🔍 Processing OCR for page 61
# 🔍 Processing OCR for page 429
# 🔍 Processing OCR for page 430
# 🔍 Processing OCR for page 431
# 🔍 Processing OCR for page 432
# 🔍 Processing OCR for page 433
# 🔍 Processing OCR for page 434
# 🔍 Processing OCR for page 435
# 🔍 Processing OCR for page 436
# 🔍 Processing OCR for page 437
# 🔍 Processing OCR for page 438
# 🔍 Processing OCR for page 439
# 🔍 Processing OCR for page 440
# 🔍 Processing OCR for page 441
# 🔍 Processing OCR for page 442
# 🔍 Processing OCR for page 443
# 🔍 Processing OCR for page 444
# 🔍 Processing OCR for page 445
# 🔍 Processing OCR for page 446
# 🔍 Processing OCR for page 447
# 🔍 Processing OCR for page 448
# 🔍 Processing OCR for page 449
# 🔍 Processing OCR for page 450
# 🔍 Processing OCR for page 451
# 🔍 Processing OCR for page 452
# 🔍 Processing OCR for page 453
# 🔍 Processing OCR for page 454
# 🔍 Processing OCR for page 455
# 🔍 Processing OCR for page 456
# 🔍 Processing OCR for page 457
# 🔍 Processing OCR for page 458
# 🔍 Processing OCR for page 459
# 🔍 Processing OCR for page 460
# 🔍 Processing OCR for page 461
# 🔍 Processing OCR for page 462
# 🔍 Processing OCR for page 463
# 🔍 Processing OCR for page 464
# 🔍 Processing OCR for page 465
# 🔍 Processing OCR for page 466
# 🔍 Processing OCR for page 467
# 🔍 Processing OCR for page 468
# 🔍 Processing OCR for page 469
# 🔍 Processing OCR for page 470
# 🔍 Processing OCR for page 471
# 🔍 Processing OCR for page 472
# 🔍 Processing OCR for page 473
# 🔍 Processing OCR for page 474
# 🔍 Processing OCR for page 475
# 🔍 Processing OCR for page 476
# 🔍 Processing OCR for page 477
# 🔍 Processing OCR for page 478
# 🔍 Processing OCR for page 479
# 🔍 Processing OCR for page 480
# 🔍 Processing OCR for page 481
# 🔍 Processing OCR for page 482
# 🔍 Processing OCR for page 483
# 🔍 Processing OCR for page 484
# 🔍 Processing OCR for page 485
# 🔍 Processing OCR for page 486
# 🔍 Processing OCR for page 487
# 🔍 Processing OCR for page 488
# 🔍 Processing OCR for page 489
# 🔍 Processing OCR for page 490
# 🔍 Processing OCR for page 491
# 🔍 Processing OCR for page 492
# 🔍 Processing OCR for page 493
# 🔍 Processing OCR for page 494
# 🔍 Processing OCR for page 495
# 🔍 Processing OCR for page 496
# 🔍 Processing OCR for page 497
# 🔍 Processing OCR for page 498
# 🔍 Processing OCR for page 499
# 🔍 Processing OCR for page 500
# 🔍 Processing OCR for page 501
# 🔍 Processing OCR for page 502
# 🔍 Processing OCR for page 503
# 🔍 Processing OCR for page 504
# 🔍 Processing OCR for page 505
# 🔍 Processing OCR for page 506
# 🔍 Processing OCR for page 507
# 🔍 Processing OCR for page 508
# 🔍 Processing OCR for page 509
# 🔍 Processing OCR for page 510
# 🔍 Processing OCR for page 511
# 🔍 Processing OCR for page 512
# 🔍 Processing OCR for page 513
# 🔍 Processing OCR for page 514
# 🔍 Processing OCR for page 515
# 🔍 Processing OCR for page 516
# 🔍 Processing OCR for page 517
# 🔍 Processing OCR for page 518
# 🔍 Processing OCR for page 519
# 🔍 Processing OCR for page 520
# 🔍 Processing OCR for page 521
# 🔍 Processing OCR for page 522
# 🔍 Processing OCR for page 523
# 🔍 Processing OCR for page 524
# 🔍 Processing OCR for page 525
# 🔍 Processing OCR for page 526
# 🔍 Processing OCR for page 527
# 🔍 Processing OCR for page 528
# 🔍 Processing OCR for page 529
# 🔍 Processing OCR for page 530
# 🔍 Processing OCR for page 531
# 🔍 Processing OCR for page 532
# 🔍 Processing OCR for page 533
# 🔍 Processing OCR for page 534
# 🔍 Processing OCR for page 535
# 🔍 Processing OCR for page 536
# 🔍 Processing OCR for page 537
# 🔍 Processing OCR for page 538
# 🔍 Processing OCR for page 539
# 🔍 Processing OCR for page 540
# 🔍 Processing OCR for page 541
# 🔍 Processing OCR for page 542
# 🔍 Processing OCR for page 543
# 🔍 Processing OCR for page 544
# 🔍 Processing OCR for page 545
# ✅ OCR results saved to: page_ocr_output.txt
# 📊 Total processed lines: 10767
# [(13013, '"333_BLOCK001_LINE001.png": "“212 -( 7/7.",'), (13014, '"333_BLOCK002_LINE002.png": "TRANG TỬ - và NAM HOA KINH",'), (13015, '"333_BLOCK003_LINE003.png": "NGUYỄN HIẾN LÊ (Giới thiệu và chú địch) TRANG TỬ và NAM HOA KINH NHÀ XUẤT BẢN VĂN HÓA - THÔNG TIN 1994",'), (13016, '"333_BLOCK004_LINE004.png": "NAM HOA KINH 5 Lần đầu tiên Nam Hoa kinh được dịch trọn bộ ra tiếng Việt uà được phôn tích kĩ từng chương một để giữ cho Trang tử những cái gì của Trang mồ trẻ lại cho người trước uà người sau những cói gì của người trước uà người squ ;",'), (13017, '"333_BLOCK004_LINE005.png": "có uậy mới đánh giá được sự cống hiến của Trang cho tư tưởng Trung Hoa.",'), (13018, '"333_BLOCK004_LINE006.png": "Những đoạn nào tối nghĩa thì được dịch giả thận trọng ghi cả hai ba cách giỏi của người trước uờ tùy chỗ, đưa ý kiến riêng của mình.",'), (13019, '"333_BLOCK005_LINE007.png": "PHẦN I GIỚI THIỆU TÁC GIẢ và .",'), (13020, '"333_BLOCK005_LINE008.png": "TÁC PHẨM",'), (13021, '"333_BLOCK006_LINE009.png": "NAM HOA KINH 9 CHƯƠNG I ^.",'), (13022, '"333_BLOCK006_LINE010.png": "` ^ ^^.",'), (13023, '"333_BLOCK006_LINE011.png": "THỜI ĐẠI VÀ ĐỜI SÔNG THỜI ĐẠI Trang tử kém Mạnh tử khoảng mười tuổi, sống ở giữa thời Chiến Quốc (-403 - 221).",'), (13024, '"333_BLOCK006_LINE012.png": "Ông sanh vào khoảng - 360, trên 40 năm sau khi thời đại loạn đó bắt đầu, và 60 năm sau khi ông mất, nó cũng chấm dứt.",'), (13025, '"333_BLOCK006_LINE013.png": "Vậy ông được chứng kiến hầu hết nhứng biến chuyển lớn của thời đó :",'), (13026, '"333_BLOCK006_LINE014.png": "Tần dùng Vệ Ưởng để biến pháp mà hùng cường lên, xưng bé (- 343) rồi xưng vương (-325) ;",'), (13027, '"333_BLOCK006_LINE015.png": "sáu nước kia (Yên, Triệu, Hàn, Ngụy, Tê, Sở) bèn hợp #r„g để chống Tần (-3ấ3), những phe hợp tung mau tan (-332), Trương Nghi đề nghị thuyết liên hoành (-311) để liên hiệp lục quốc mà tôn Tần, do đó Tần lại càng mạnh thêm, thắng được Ngụy, Hàn, Sở, rồi xưng đế (-288), diệt Tống, ức hiếp Triệu.",'), (13028, '"333_BLOCK006_LINE016.png": "Trước khi mất, chắc Trang tử đã đoán được xu thế của thời đại :",'), (13029, '"333_BLOCK006_LINE017.png": "thế nào rồi Tần cúng sẽ thay Chu, làm thiên tử mà thống nhất Trung Quốc.",'), (13030, '"333_BLOCK006_LINE018.png": "Như trong Chiến Quốc Sách( trang 10, chúng tôi đã nói, sự dùng năm -403 để phân chia hai thời Xuân Thu và (1) Lá Bối xuất bản, 1969, Sài Gòn.",'), (13031, '"333_BLOCK007_LINE019.png": "10 TRANG TỬ Chiến Quốc không dựa trên một biến cố nào quan trọng (năm đó chỉ là năm lên ngôi của Ủy Liệt vương nhà Chu), mà lịch sử và xã hội Trung Hoa suốt hai thời Xuân Thu và Chiến Quốc biến chuyển liên tục, không hề gián đoạn, từ chế độ phong kiến tới chế độ quân chủ chuyên chế, từ tình trạng phân li tới tình trạng thống nhất.",'), (13032, '"333_BLOCK007_LINE020.png": "Tuy nhiên, xét chung, chúng ta vẫn thấy hai thời đó có nhiều điểm khác nhau :",'), (13033, '"333_BLOCK007_LINE021.png": "Xuân Thu là thời các vị bá chủ (như vua Hoàn công nước TÈ) mượn uy danh của Thiên tử, tức vua nhà Chu mà ra lệnh cho các chư hầu :",'), (13034, '"333_BLOCK007_LINE022.png": "Thiên tứ thời đó tuy không có quyền, nhưng còn danh phận, các vị bá chủ chưa dám khinh ;",'), (13035, '"333_BLOCK007_LINE023.png": "thời Chiến Quốc, trái lại, vua các nước lớn như Tần, Tè, Ngụy, Sở đều xưng vương, chẳng coi Thiên tử Ta gì cả ;",'), (13036, '"333_BLOCK007_LINE024.png": "Thời Xuân Thu, chế độ chính trị chỉ biến chuyển lần lần thôi, vì các vua chúa còn trọng dư luận ít nhiều ;",'), (13037, '"333_BLOCK007_LINE025.png": "qua thời Chiến Quốc, vua các cường quốc không đoái gì tới cổ pháp, cổ lễ, can đảm làm những cuộc cách mạng về pháp độ, như cuộc biến pháp của Vệ Ưởng nằm -359 đời Tần Hiến công ;",'), (13038, '"333_BLOCK007_LINE026.png": ""hời Xuân Thu giới quý tộc còn nắm được nhiều quyền lớn, cha truyền con nối, qua thời Chiến Quốc, đặc quyềw “đó gần như hoàn toàn bị tiêu diệt, và rất nhiều \' người.",'), (13039, '"333_BLOCK007_LINE027.png": "rong giới bình dân lên làm  ...

# %%
# Example usage:
if __name__ == "__main__":
    # Method 1: Extract embedded images and OCR them
    # results = process_images_with_ocr("your_pdf_file.pdf", "image_ocr_output.txt")
    
    # Method 2: Convert each page to image and OCR (recommended for scanned PDFs)
    results = process_pdf_pages_ocr("/home/octoopt/workspace/projects/learn-from-basics/nlp-vietnamese-phd/temp/TRANG TỬ NAM HOA KINH.pdf", "page_ocr_output.txt")
    
    
    print(results)
